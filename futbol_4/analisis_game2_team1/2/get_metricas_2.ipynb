# %%
import numpy as np
import sys,os,json
from collections import Counter
import glob
from itertools import chain
import networkx as nx
from plotter_lib import *

#import matplotlib.pyplot as plt

# %%
arxs_S0 = glob.glob("/home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0*")
arxs_S1 = glob.glob("/home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S1*")

# %% [markdown]
# Busco jugadores que esten en todas las redes

# %%
def get_lista_jugadores(arxs):

    def f(arx):
        d = json.load(open(arx,'r' ))
        links = list(d.keys())
        return list( map( lambda link: link.split('_'), links ) )

    l1 = list(chain.from_iterable(list(map( f , arxs))) )
    l2 = sorted(set(list(chain.from_iterable(l1) ) ), key= lambda s: int(s.split("r")[-1]))

    return(l2)

j0 = get_lista_jugadores(arxs_S0)
j1 = get_lista_jugadores(arxs_S1)

players = sorted(set(j0).intersection(set(j1)), key= lambda s: int(s.split("r")[-1]) )

# %% [markdown]
# Calculo de metricas de las redes S0

# %%
def get_undirected_edgelist(d):

    red={}
    seen=set()
    
    for players, w in d.items():
        n1, n2 = players.split('_')
        

        if (n1,n2) not in seen:

            if (n2,n1) not in seen:

                seen.add((n1,n2))

                red[(n1,n2)]=w

            else:
                red[(n2,n1)]+=w

        else:
            red[(n1,n2)]+=w
    # ------------------------------------------
    
    
    return [ "%s %s {'weight':%d}" % (nodos[0],nodos[1],w) for nodos,w in red.items() ]

def get_directed_graph(d):

    G = nx.DiGraph()
    
    for players, w in d.items():
        n1, n2 = players.split('_')
        G.add_edge(n1, n2, weight=w)

    
    return G

# %%
data0 = {  player:{ "c":[],"ec":[], "bc":[] } for player in players  }

for arx in arxs_S0:

    print (arx)

    G = get_directed_graph( json.load(open(arx,'r')) )       
    
    # clustering
    c= nx.clustering(G, weight="weight")
    
    # centralidad 
    ec = nx.eigenvector_centrality(G, weight="weight")
    
    bc = nx.betweenness_centrality(G, weight="weight")

    for player in players:

        try:
            data0[player]['c'].append( c[player] )

            data0[player]['ec'].append( ec[player] )

            data0[player]['bc'].append( bc[player] )
        except:
            None


print (data0)
# Out:
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_4470.json
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_3447.json
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_2534.json
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_740.json
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_5442.json
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_2121.json
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_5302.json
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_3606.json
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_2590.json
# /home/chacoma/Lineas/football_4/data/passing_network/game2/team1/S0_4600.json
# {'Player1': {'c': [0.3846868746994492, 0.5222196476187884, 0.33205135944472763, 0.1643977829995265, 0.2901909568194467, 0, 0.2285967325938591, 0.3548608009607452, 0.33205135944472763, 0.3846868746994492], 'ec': [0.25203003504023863, 0.37626384888058934, 0.4005885559416389, 0.27118120882931723, 0.23864002715122218, 0.034816614640199105, 0.25063901454703863, 0.30703753996860583, 0.38758608427251123, 0.25203003504023863], 'bc': [0.030303030303030304, 0.0, 0.0162037037037037, 0.24652777777777776, 0.011111111111111112, 0.0, 0.02962962962962963, 0.0, 0.020833333333333332, 0.030303030303030304]}, 'Player2': {'c': [0, 0.4530046269696681, 0.2987363890032385, 0.24363842091096136, 0.24999999999999997, 0.08333333333333333, 0, 0.22948330468716058, 0.2987363890032385, 0], 'ec': [0.037020608756788385, 0.2697781609605596, 0.28098613057081384, 0.1813758763303343, 0.09464977908472158, 0.09105579595296884, 0.05535054041876766, 0.13464341265281785, 0.27224655886220345, 0.037
for arx in arxs_S1:

    print (arx)

    edgelist = get_undirected_edgelist( json.load(open(arx,'r')) )

    G = nx.parse_edgelist(edgelist, nodetype = str)
        
    
    # clustering
    c= nx.clustering(G, weight="weight")
    
    # centralidad 
    ec = nx.eigenvector_centrality(G, weight="weight")
    
    bc = nx.betweenness_centrality(G, weight="weight")

    for player in players:

        try:
            data1[player]['c'].append( c[player] )

            data1[player]['ec'].append( ec[player] )

            data1[player]['bc'].append( bc[player] )
        except:
            None


print (data1)
# Out:
# game2/team1/S1_1190.json
# game2/team1/S1_4841.json
# game2/team1/S1_1093.json
# game2/team1/S1_2682.json
# game2/team1/S1_2243.json
# game2/team1/S1_3955.json
# game2/team1/S1_4688.json
# game2/team1/S1_659.json
# game2/team1/S1_488.json
# game2/team1/S1_5595.json
# game2/team1/S1_4973.json
# {'Player1': {'c': [0.1834404027163681, 0.2715628015441625, 0.19723386019870787, 0.23613480420992616, 0.14885342253960498, 0.17579327387280913, 0.2449790513550314, 0.11814083235404829, 0.15470461213593129, 0.1696303406945172, 0.3753960127240147], 'ec': [0.19701839624519338, 0.4001819852676246, 0.2704271489092145, 0.2141400874514356, 0.15863576494173434, 0.2549900407701763, 0.32600773681150413, 0.2143257954166605, 0.2656357101208176, 0.1695152777754525, 0.40797468870658193], 'bc': [0.1597222222222222, 0.0, 0.060185185185185175, 0.009259259259259259, 0.0, 0.2, 0.07407407407407407, 0.2731481481481481, 0.18749999999999997, 0.02962962962962963, 0.0]}, 'Player2': {'c': [0.28238473118027824, 0.09614997135382723, 0.29065977944321375, 0.264302878604668, 0.130527053914765, 0.2128858835538857, 0.10095114404622996, 0.20990002940011798, 0.4120713058021166, 0.20998684164914552, 0.2173280699929915], 'ec': [0.3427979428180099, 0.09564694669783408, 0.2908784634555471, 0.2127407830726245, 0.12412521633225301, 0.15066309445075626, 0.08370238301131488, 0.21161338722489442, 0.1495445138633292, 0.05721428674639646, 0.09768774517623069], 'bc': [0.027777777777777776, 0.11111111111111112, 0.1532407407407407, 0.0, 0.13425925925925924, 0.11851851851851852, 0.11925925925925927, 0.013888888888888888, 0.0, 0.019259259259259257, 0.007619047619047619]}, 'Player3': {'c': [0.2291935907902359, 0.06666666666666667, 0.20989943907613667, 0.3581798543833686, 0.264844748497999, 0.1865090280198939, 0.16666666666666666, 0.14301967915510766, 0.1552081030066451, 0.15012059001123787, 0.16798947331931638], 'ec': [0.3096737168658118, 0.0860863638717388, 0.23247275348956836, 0.23101037641254724, 0.17859642096356637, 0.17893450449678353, 0.055192479042571026, 0.17933708910052634, 0.09506590319485403, 0.07210629734707993, 0.11183243748522097], 'bc': [0.0, 0.07777777777777778, 0.23796296296296293, 0.0, 0.0, 0.08148148148148147, 0.0, 0.07638888888888888, 0.1435185185185185, 0.07555555555555556, 0.007407407407407408]}, 'Player4': {'c': [0.18738532100854605, 0.21881012204616992, 0.2597189862934816, 0.14991325462440286, 0.2645668419946999, 0.11499282992367436, 0.10755564081655737], 'ec': [0.4437039557830605, 0.49483439410677826, 0.43149453165895457, 0.45809401214564155, 0.0644637662615112, 0.6056745877195737, 0.5590660855766135], 'bc': [0.20138888888888887, 0.042592592592592585, 0.006944444444444444, 0.037037037037037035, 0.0, 0.0, 0.34259259259259256]}, 'Player5': {'c': [0.24350438438715796, 0.14901276379726164, 0.3207594281354286, 0.18490425319371753, 0.1766311821808784, 0.23468855113368334, 0.13375220195626583, 0.10762852161460264, 0.11377975662381028, 0.10878274414468232, 0.13181376257635147], 'ec': [0.38509182552729837, 0.3892692662443948, 0.36384532312427925, 0.38170498982259915, 0.45153128220035665, 0.5166377761023557, 0.4868060692011307, 0.23812862314743913, 0.25497093727945025, 0.3018363740943507, 0.37008342776937214], 'bc': [0.0, 0.28740740740740744, 0.034722222222222224, 0.09722222222222221, 0.0324074074074074, 0.0, 0.39037037037037037, 0.07870370370370369, 0.034722222222222224, 0.1940740740740741, 0.40206830206830213]}, 'Player6': {'c': [0.20796681049444624, 0.1734233944206777, 0.2883742953732656, 0.16742941420670512, 0.12965431594720944, 0.3095744823082097, 0.22719093668900464, 0.19941482078442294, 0.14344391028054865, 0.14045573632513542, 0.17194042671560142], 'ec': [0.42783453680508504, 0.3313400491818446, 0.396099458759506, 0.45007354087619084, 0.27605745071902926, 0.4379441024577648, 0.4617125494430731, 0.46927450459139314, 0.3803776085477751, 0.4368463103416856, 0.3452288535813245], 'bc': [0.25, 0.15962962962962962, 0.07731481481481481, 0.037037037037037035, 0.3379629629629629, 0.007407407407407408, 0.044444444444444446, 0.037037037037037035, 0.0810185185185185, 0.07925925925925925, 0.1777104377104377]}, 'Player7': {'c': [0, 0.213441352335477, 0.24205294103735042, 0.1412931869621423, 0.21423505368928022, 0.19657782356164874, 0.20082827906851233, 0.1158193008740138 ...

# %%
json.dump(data1, open("player_metrica_S1.json","w"))

# %% [markdown]
# Plots

# %%
player2n = { p:int(p.split('r')[-1]) for p in players }
z_alpha = 1#1.96

fig,ax = plt.subplots(3,1, figsize=(12,10))

for i, metrica in enumerate(['c','ec','bc']):


    x,y0,y1, err0, err1, = [],[],[],[],[]

    for player in players:

        n0, n1 =  len(data0[player][metrica])  , len(data1[player][metrica]) 
        mu0, mu1 = np.mean(data0[player][metrica])  , np.mean(data1[player][metrica]) 
        sd0, sd1 = np.std(data0[player][metrica])  , np.std(data1[player][metrica]) 


        x.append( player2n[player]  )  
        y0.append( mu0 )
        y1.append( mu1 )

        err0.append( sd0*z_alpha/np.sqrt(n0) )
        err1.append( sd1*z_alpha/np.sqrt(n1) )


    ax[i].errorbar(x, y0, err0, c='red', linewidth=0, alpha=0.5 ,elinewidth=3,capsize=4) 

    ax[i].errorbar(x, y1, err1, c='blue', linewidth=0, alpha=0.5,elinewidth=3,capsize=4)

    ax[i].set_ylabel(metrica)

plt.show()

# %%
y1
# Out:
# [0.09031986531986531,
#  0.06408489658489659,
#  0.06364478114478114,
#  0.09007936507936508,
#  0.14106344833617565,
#  0.11716559534741354,
#  0.07778094800822072,
#  0.09068867243867243,
#  0.13894562508198868,
#  0.06576599326599325,
#  0.044444444444444446,
#  0.11327681577681578,
#  0.1918518518518518]
